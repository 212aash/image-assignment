# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
im=plt.imread(r"C:\Users\Aashir Ali Khan\Desktop\lasth\second\aashir\\1.jpg")
print(type(im))
print(im.shape)
print()
#%pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
from PIL import Image as im

for i in range(20):
    img=mpimg.imread(r'C:\Users\Aashir Ali Khan\Desktop\lasth\second\aashir\\'+str(i+1)+'.jpg')
    imgplot = plt.imshow(img)
    plt.show()

list1=[]
for i in range(20):
    im1=(im.open(r'C:\Users\Aashir Ali Khan\Desktop\lasth\second\aashir\\'+str(i+1)+'.jpg'))
    im1=im1.resize((500,500),im.ANTIALIAS)
 #   print(plt.imshow(im1))
    im1.save('resize'+str(i+1)+'.jpg')
    list1.append(np.array(im1))
#    print(a1)
print(list1[19])
# Out:
# <class 'numpy.ndarray'>
# (1080, 1920, 3)
# [[[204 233 231]
#   [203 232 231]
#   [206 234 235]
#   ...
#   [213 237 234]
#   [211 236 233]
#   [211 236 233]]
#
#  [[204 235 231]
#   [204 233 232]
#   [206 234 235]
#   ...
#   [213 235 233]
#   [211 234 232]
#   [211 234 232]]
#
#  [[205 234 232]
#   [204 233 232]
#   [205 233 234]
#   ...
#   [213 235 233]
#   [213 235 233]
#   [213 235 233]]
#
#  ...
#
#  [[147 162 157]
#   [149 164 159]
#   [150 166 161]
#   ...
#   [137 152 149]
#   [139 154 151]
#   [139 153 153]]
#
#  [[143 158 153]
#   [145 160 155]
#   [148 163 158]
#   ...
#   [142 157 154]
#   [143 158 156]
#   [144 158 158]]
#
#  [[138 153 148]
#   [141 156 151]
#   [144 159 154]
#   ...
#   [141 156 153]
#   [142 157 155]
#   [142 156 156]]]
